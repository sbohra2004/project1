# %%
#df

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/archive (15).zip')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Check for missing values
print(df.isnull().sum())    #missing values and number of missing values


# Check for duplicate rows
print(df.duplicated().sum())

# Data types of columns
print(df.dtypes)
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
# 0
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histogram for glucose
sns.histplot(df['Glucose'])
plt.title('Glucose Distribution')
plt.show()

# Boxplot for BMI
sns.boxplot(x=df['BMI'])
plt.title('BMI Distribution')
plt.show()

# Boxplot for Age
sns.boxplot(x=df['Age'])
plt.title('Age Distribution')
plt.show()

# %%
# Count plot for Outcome (target variable)
sns.countplot(x='Outcome', data=df)    #frequency
plt.title('Outcome Distribution (Diabetes)')
plt.show()

# %%
# Boxplot to compare Glucose levels by Outcome
sns.boxplot(x='Outcome', y='Glucose', data=df)
plt.title('Glucose Levels by Outcome comparison')
plt.show()

# Boxplot for BMI by Outcome
sns.boxplot(x='Outcome', y='BMI', data=df)
plt.title('BMI Distribution by Outcome')
plt.show()

# %%
# Correlation matrix
correlation = df.corr()


# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot=True,cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
Age_sorted=df.sort_values(by='Age',ascending=True)
Age_sorted
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 255            1      113             64             35        0  33.6
# 60             2       84              0              0        0   0.0
# 102            0      125             96              0        0  22.5
# 182            1        0             74             20       23  27.7
# 623            0       94             70             27      115  43.5
# ..           ...      ...            ...            ...      ...   ...
# 123            5      132             80              0        0  26.8
# 684            5      136             82              0        0   0.0
# 666            4      145             82             18        0  32.5
# 453            2      119              0              0        0  19.6
# 459            9      134             74             33       60  25.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 255                     0.543   21        1
# ...

# %%
Glucose_sorted=df.sort_values(by='Glucose',ascending=False)
Glucose_sorted
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661            1      199             76             43        0  42.9
# 561            0      198             66             32      274  41.3
# 228            4      197             70             39      744  36.7
# 8              2      197             70             45      543  30.5
# 579            2      197             70             99        0  34.7
# ..           ...      ...            ...            ...      ...   ...
# 342            1        0             68             35        0  32.0
# 349            5        0             80             32        0  41.0
# 502            6        0             68             41        0  39.0
# 182            1        0             74             20       23  27.7
# 75             1        0             48             20        0  24.7
#
#      DiabetesPedigreeFunction  Age  Outcome
# 661                     1.394   22        1
# ...
